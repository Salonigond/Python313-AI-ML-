# %% [markdown]
# #### This is my first program

# %%
# Program using python
a = [1, 2, 3, 4, 5]
b = ['apple', 'banana', 'cherry']
c = [1, 'hello', 3.14, True]

print (a)
print (b)
print (c)
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana', 'cherry']
# [1, 'hello', 3.14, True]

# %%
# Program 2 Accessing list element
print(a[0])
print(a[-1])
print(a[1:4])
# Out:
# 1
# 5
# [2, 3, 4]

# %%
# Adding elements into list
a.append(6)
print("After append", a)
a.insert(0,5)
print("after insert", a)
a.extend([15, 20, 25])
print("after extend", a)
a.clear()
print("after clear", a)
# Out:
# After append [6]
# after insert [5, 6]
# after extend [5, 6, 15, 20, 25]
# after clear []

# %%
# Remove elements from the list 
a=[1,2,3,4,5,6,7]
a.remove(2)
print("After remove", a)
popped_value= a.pop(1)
print("after popped", a)
del(a[0])
print("after delete", a)
# Out:
# After remove [1, 3, 4, 5, 6, 7]
# after popped [1, 4, 5, 6, 7]
# after delete [4, 5, 6, 7]

# %%
# Converting integer to string and using subscript notation
number= 42
number_str= str(number)
print(number_str[0])
# Out:
# 4
