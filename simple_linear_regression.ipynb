# %% [markdown]
# # Simple linear regression program with error analysis and visilution

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
#load the dataset
dataset = pd.read_csv("salary_data.csv")

# extract independent and dependent
X= dataset[['YearExperience']]
y= dataset['Salary']

# %%
#Visulize dataset
plt.scatter(X, y, color= 'blue')
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.title("Data visualization")
plt.show()

# %%
# Train linear Regression model
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#Prediction 
y_pred=model.predict(X)
print(y_pred)
# Out:
# [35000. 40000. 45000. 50000. 55000. 60000.]

# %%
# clalcuate error
mae=mean_absolute_error(y, y_pred)
mse=mean_squared_error(y, y_pred)
rsme=np.sqrt(mse)
print("Mean absolute Error:", mae)
print("Mean absolute Error:", mse)
print("Root Mean Squared Error:", rsme)
# Out:
# Mean absolute Error: 0.0
# Mean absolute Error: 0.0
# Root Mean Squared Error: 0.0

# %%
#regression line visulization
plt.scatter(X,y, color='blue', label='Actual Data')
plt.plot(X,y, color='red', label='Predicted Data')
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.title("Data visualization")
plt.show()
