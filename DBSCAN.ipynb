# %%
#import libraries
from sklearn.datasets import make_blobs

#matplotlib for plotting
from matplotlib import pyplot as plt
from matplotlib import style

# %%
style.use("fivethirtyeight")

X, y = make_blobs(n_samples=100, centers=3, cluster_std=1, n_features=2)

plt.scatter(X[:, 0], X[:, 1], s=40, color='g')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
plt.clf()

# %%
y
# Out:
# array([0., 1., 2.])

# %%
X,y = make_blobs(n_samples=[3,3,4],centers=None,n_features=2,random_state=0)

# %%
print(X.shape)
# Out:
# (10, 2)

# %%
y
# Out:
# array([0, 1, 2, 0, 2, 2, 2, 1, 1, 0])

# %%
import numpy as np
x=np.arange(6)
x=x.reshape((2,3))
x
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.zeros_like(x)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
import numpy as np

x = np.arange(6)
x = x.reshape((2, 3))

np.zeros_like(x)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
y=np.arange(3,dtype=float)
y
# Out:
# array([0., 1., 2.])

# %%
np.zeros_like(y)
# Out:
# array([0., 0., 0.])

# %%
from sklearn.cluster import DBSCAN
import numpy as np
X=np.array([[1,2],[2,2],[2,3],[8,7],[8,8],[25,80]])
clustering = DBSCAN(eps=3,min_samples=2).fit(X)
clustering.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1])

# %%
clustering
# Out:
# DBSCAN(eps=3, min_samples=2)

# %%
core = np.array([True,False,True,False,True])
#~core will negate the boolean values negated_core = ~core
negated_core=~core
print(negated_core)
# Out:
# [False  True False  True False]
