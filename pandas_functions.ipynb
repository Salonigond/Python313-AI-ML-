# %%
import pandas as pd
#reading csv file
df=pd.read_csv("Team.csv")
df
# Out:
#      Name    Team  Number Position   Age
# 0   avery  boston     0.0       GP  25.0
# 1   john   boston    30.0       SG  27.0
# 2   jonas  boston    30.0       PF  29.0
# 3  jordan  boston     8.0       PG  21.0
# 4   terry  boston     NaN        C  22.0
# 5   jared  boston    12.0       SG   NaN
# 6    evan  boston    11.0       SG  27.0

# %%
#head() method
df.head(5)
# Out:
#      Name    Team  Number Position   Age
# 0   avery  boston     0.0       GP  25.0
# 1   john   boston    30.0       SG  27.0
# 2   jonas  boston    30.0       PF  29.0
# 3  jordan  boston     8.0       PG  21.0
# 4   terry  boston     NaN        C  22.0

# %%
#tail() function
df.tail(4)
# Out:
#      Name    Team  Number Position   Age
# 3  jordan  boston     8.0       PG  21.0
# 4   terry  boston     NaN        C  22.0
# 5   jared  boston    12.0       SG   NaN
# 6    evan  boston    11.0       SG  27.0

# %%
#info function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Team      7 non-null      object
#  2   Number    6 non-null      float64
#  3   Position  7 non-null      object
#  4   Age       6 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 412.0+ bytes

# %%
#dtypes() function
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# dtype: object

# %%
#shape() function
df.shape
# Out:
# (7, 5)

# %%
#size() function
df.size
# Out:
# 35

# %%
#describe() function
df.describe
# Out:
# <bound method NDFrame.describe of      Name    Team  Number Position   Age
# 0   avery  boston     0.0       GP  25.0
# 1   john   boston    30.0       SG  27.0
# 2   jonas  boston    30.0       PF  29.0
# 3  jordan  boston     8.0       PG  21.0
# 4   terry  boston     NaN        C  22.0
# 5   jared  boston    12.0       SG   NaN
# 6    evan  boston    11.0       SG  27.0>
