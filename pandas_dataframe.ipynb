# %%
import pandas as pd
#create a dictory
data = {'Name':['Bob','Alice','Joy'],'Age':[25,30,35],'City':['New york', 'London', 'Paris']}

#create a dataframe from the dictionary
df=pd.DataFrame(data, columns=['Name','Age','City'])
print(df)
# Out:
#     Name  Age      City
# 0    Bob   25  New york
# 1  Alice   30    London
# 2    Joy   35     Paris

# %%
#set the 'Name' column as index
df.set_index('Name', inplace=True)
df
# Out:
#        Age      City
# Name
# Bob     25  New york
# Alice   30    London
# Joy     35     Paris
